# %%
print(navya)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1577426464.py in <cell line: 0>()
# ----> 1 print(navya)
#
# NameError: name 'navya' is not defined

# %%
print("Name:","Navya Shree C N ")
print("Gender:","Female")
print("Age:",21)
print("Email:","navyashree.n25@gmail.com")
print("Year of Graduation:",2026)
# Out:
# Name: Navya Shree C N
# Gender: Female
# Age: 21
# Email: navyashree.n25@gmail.com
# Year of Graduation: 2026

# %%
print(10)
print(20)
print(30)
# Out:
# 10
# 20
# 30

# %% [markdown]
# text should be inside a double notations(" ")
# number doesn't need any quotations

# %%
print("apple",10,20)
# Out:
# apple 10 20

# %% [markdown]
# number and text should be in single line

# %%
print("Fruit=","Mango")
print("Number=",10)
# Out:
# Fruit= Mango
# Number= 10
